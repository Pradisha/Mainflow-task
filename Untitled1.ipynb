# %%
from pptx import Presentation
from pptx.util import Inches

# Create a presentation object
prs = Presentation()

# Title Slide
slide_1 = prs.slides.add_slide(prs.slide_layouts[0])
title = slide_1.shapes.title
subtitle = slide_1.placeholders[1]

title.text = "Flipkart Review Sentiment Analysis"
subtitle.text = "NTCC Summer Internship Report\nPradisha"

# Abstract Slide
slide_2 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_2.shapes.title
content = slide_2.placeholders[1]

title.text = "Abstract"
content.text = (
    "• Aim of the project: Analyzing customer reviews to uncover sentiments and actionable insights.\n"
    "• Utilized techniques: Data preprocessing, sentiment analysis, data visualization."
)

# Introduction Slide
slide_3 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_3.shapes.title
content = slide_3.placeholders[1]

title.text = "Introduction"
content.text = (
    "• Importance of sentiment analysis in e-commerce.\n"
    "• Purpose of the project: Improve understanding of customer feedback on Flipkart."
)

# Objectives Slide
slide_4 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_4.shapes.title
content = slide_4.placeholders[1]

title.text = "Objectives"
content.text = (
    "• Analyze customer sentiments in reviews.\n"
    "• Identify common themes in positive and negative feedback.\n"
    "• Provide strategic recommendations based on insights."
)

# Feasibility Study Slide
slide_5 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_5.shapes.title
content = slide_5.placeholders[1]

title.text = "Feasibility Study"
content.text = (
    "• Activities & Layouts: Overview of the data collection and preprocessing activities.\n"
    "• Software Dev Life Cycle:\n"
    "   - Planning: Defined objectives and scope.\n"
    "   - Design: Collected dataset and drafted questions.\n"
    "   - Development: Preprocessed data using Python libraries.\n"
    "   - Testing: Verified visualizations for accuracy.\n"
    "   - Deployment: Prepared the final report with insights."
)

# Architecture Slide
slide_6 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_6.shapes.title
content = slide_6.placeholders[1]

title.text = "Architecture"
content.text = (
    "• Data collection and preprocessing steps.\n"
    "• Sentiment analysis and data visualization pipeline."
)

# Data Analysis & Visualization Slide
slide_7 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_7.shapes.title
content = slide_7.placeholders[1]

title.text = "Data Analysis & Visualization"
content.text = (
    "• Data Analysis:\n"
    "   - Distribution of ratings.\n"
    "   - Common themes in positive and negative reviews.\n"
    "   - Average ratings per product.\n"
    "• Visualization:\n"
    "   - Examples of pie charts, bar charts, and word clouds."
)

# Conclusion Slide
slide_8 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_8.shapes.title
content = slide_8.placeholders[1]

title.text = "Conclusion"
content.text = (
    "• Key findings and insights from the analysis.\n"
    "• Recommendations for improving customer satisfaction and product offerings."
)

# References Slide
slide_9 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_9.shapes.title
content = slide_9.placeholders[1]

title.text = "References"
content.text = "List any sources or tools used in the project."

# Save the presentation
prs.save("Flipkart_Review_Sentiment_Analysis_Presentation.pptx")
