# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Flipkart_project\\Dataset-SA.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info
# Out:
# <bound method DataFrame.info of                                              product_name product_price Rate  \
# 0       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 1       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 2       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# 3       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    1
# 4       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# ...                                                   ...           ...  ...
# 205047  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205048  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205049  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    3
# 205050  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205051  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    4
#
# ...

# %%
 data.shape
# Out:
# (205052, 6)

# %%
data.describe()
# Out:
#                                              product_name product_price  \
# count                                              205052        205052
# unique                                                958           525
# top     cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299
# freq                                                 6005          9150
#
#           Rate     Review Summary Sentiment
# count   205052     180388  205041    205052
# unique       8       1324   92923         3
# top          5  wonderful    good  positive
# freq    118765       9016   17430    166581

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#                                              product_name product_price Rate  \
# 0       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 1       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 2       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# 3       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    1
# 4       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# ...                                                   ...           ...  ...
# 205045  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205046  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205049  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    3
# 205050  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205051  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    4
#
# ...

# %%
data.isnull()
# Out:
#         product_name  product_price   Rate  Review  Summary  Sentiment
# 0              False          False  False   False    False      False
# 1              False          False  False   False    False      False
# 2              False          False  False   False    False      False
# 3              False          False  False   False    False      False
# 4              False          False  False   False    False      False
# ...              ...            ...    ...     ...      ...        ...
# 205045         False          False  False   False    False      False
# 205046         False          False  False   False    False      False
# 205049         False          False  False   False    False      False
# 205050         False          False  False   False    False      False
# 205051         False          False  False   False    False      False
#
# [170677 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# product_name         0
# product_price        0
# Rate                 0
# Review           16202
# Summary             10
# Sentiment            0
# dtype: int64

# %%
data.notnull()
# Out:
#         product_name  product_price  Rate  Review  Summary  Sentiment
# 0               True           True  True    True     True       True
# 1               True           True  True    True     True       True
# 2               True           True  True    True     True       True
# 3               True           True  True    True     True       True
# 4               True           True  True    True     True       True
# ...              ...            ...   ...     ...      ...        ...
# 205045          True           True  True    True     True       True
# 205046          True           True  True    True     True       True
# 205049          True           True  True    True     True       True
# 205050          True           True  True    True     True       True
# 205051          True           True  True    True     True       True
#
# [170677 rows x 6 columns]

# %%
data.isnull().sum().sum()
# Out:
# 16212

# %%
data1= data.fillna(value=3)

# %%
data1
# Out:
#                                              product_name product_price Rate  \
# 0       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 1       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 2       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# 3       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    1
# 4       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# ...                                                   ...           ...  ...
# 205045  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205046  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205049  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    3
# 205050  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205051  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    4
#
# ...

# %%
data1.isnull().sum().sum()
# Out:
# 0

# %%
data2 = data.fillna(method = "pad")
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_28112\289779391.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data2 = data.fillna(method = "pad")

# %%
data2
# Out:
#                                              product_name product_price Rate  \
# 0       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 1       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 2       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# 3       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    1
# 4       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# ...                                                   ...           ...  ...
# 205045  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205046  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205049  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    3
# 205050  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205051  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    4
#
# ...

# %%
data3= data.fillna(method = "bfill")
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_28112\1755971053.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3= data.fillna(method = "bfill")

# %%
data3
# Out:
#                                              product_name product_price Rate  \
# 0       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 1       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 2       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# 3       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    1
# 4       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# ...                                                   ...           ...  ...
# 205045  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205046  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205049  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    3
# 205050  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    5
# 205051  cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299    4
#
# ...

# %%
import numpy as np

# %%
from scipy import stats

# %%
data1.columns
# Out:
# Index(['product_name', 'product_price', 'Rate', 'Review', 'Summary',
#        'Sentiment'],
#       dtype='object')

# %%
data1.drop(["product_name"], axis=1, inplace = True)
data1.drop(["Review"], axis=1, inplace = True)
data1.drop(["Sentiment"], axis=1, inplace = True)
data1.columns
# Out:
# Index(['product_price', 'Rate'], dtype='object')

# %%
data2.describe()
# Out:
#                                              product_name product_price  \
# count                                              170677        170677
# unique                                                958           525
# top     cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299
# freq                                                 4362          6859
#
#           Rate           Review Summary Sentiment
# count   170677           170677  170677    170677
# unique       8             1324   92923         3
# top          5  waste of money!    good  positive
# freq     96661            14807    7089    134701
